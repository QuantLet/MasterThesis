# %%
#loading the data from an excel file
import pandas as pd
df = pd.read_excel('Coin_Metrics_Network_Data_2023-03-14T12-27.xlsx', index_col=0) 
df.index = pd.to_datetime(df.index)
df
# Out:
#             BTC / USD Denominated Closing Price  \
# Time
# 2009-01-03                                  NaN
# 2009-01-04                                  NaN
# 2009-01-05                                  NaN
# 2009-01-06                                  NaN
# 2009-01-07                                  NaN
# ...                                         ...
# 2023-03-09                         20349.814173
# 2023-03-10                         20240.406695
# 2023-03-11                         20585.234329
# 2023-03-12                         22065.980036
# 2023-03-13                         24154.429095
#
#             BTC / Mean Tx Fee (native units)  BTC / Mean Hash Rate  \
# Time
# 2009-01-03                               NaN                   NaN
# 2009-01-04                               NaN                   NaN
# 2009-01-05                               NaN                   NaN
# 2009-01-06                               NaN                   NaN
# ...

# %%
import numpy as np
df['ETH / USD Denominated Closing Price'] = np.log(df['ETH / USD Denominated Closing Price']).diff()
df['ETH / Mean Hash Rate'] = np.log(df['ETH / Mean Hash Rate']).diff()
df['ETH / Tx per Second Cnt'] = np.log(df['ETH / Tx per Second Cnt']).diff()
df['ETH / Mean Tx Fee (native units)'] = np.log(df['ETH / Mean Tx Fee (native units)']).diff()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['BTC / USD Denominated Closing Price'] = np.log(df['BTC / USD Denominated Closing Price']).diff()
df['BTC / Mean Hash Rate'] = np.log(df['BTC / Mean Hash Rate']).diff()
df['BTC / Tx per Second Cnt'] = np.log(df['BTC / Tx per Second Cnt']).diff()
df['BTC / Mean Tx Fee (native units)'] = np.log(df['BTC / Mean Tx Fee (native units)']).diff()

# %%
df['ETC / USD Denominated Closing Price'] = np.log(df['ETC / USD Denominated Closing Price']).diff()
df['ETC / Mean Hash Rate'] = np.log(df['ETC / Mean Hash Rate']).diff()
df['ETC / Tx per Second Cnt'] = np.log(df['ETC / Tx per Second Cnt']).diff()
df['ETC / Mean Tx Fee (native units)'] = np.log(df['ETC / Mean Tx Fee (native units)']).diff()

# %%
df['LTC / USD Denominated Closing Price'] = np.log(df['LTC / USD Denominated Closing Price']).diff()
df['LTC / Mean Hash Rate'] = np.log(df['LTC / Mean Hash Rate']).diff()
df['LTC / Tx per Second Cnt'] = np.log(df['LTC / Tx per Second Cnt']).diff()
df['LTC / Mean Tx Fee (native units)'] = np.log(df['LTC / Mean Tx Fee (native units)']).diff()

# %%
df['BTG / USD Denominated Closing Price'] = np.log(df['BTG / USD Denominated Closing Price']).diff()
df['BTG / Mean Hash Rate'] = np.log(df['BTG / Mean Hash Rate']).diff()
df['BTG / Tx per Second Cnt'] = np.log(df['BTG / Tx per Second Cnt']).diff()
df['BTG / Mean Tx Fee (native units)'] = np.log(df['BTG / Mean Tx Fee (native units)']).diff()

# %%
df['DOGE / USD Denominated Closing Price'] = np.log(df['DOGE / USD Denominated Closing Price']).diff()
df['DOGE / Mean Hash Rate'] = np.log(df['DOGE / Mean Hash Rate']).diff()
df['DOGE / Tx per Second Cnt'] = np.log(df['DOGE / Tx per Second Cnt']).diff()
df['DOGE / Mean Tx Fee (native units)'] = np.log(df['DOGE / Mean Tx Fee (native units)']).diff()

# %%
df['XMR / USD Denominated Closing Price'] = np.log(df['XMR / USD Denominated Closing Price']).diff()
df['XMR / Mean Hash Rate'] = np.log(df['XMR / Mean Hash Rate']).diff()
df['XMR / Tx per Second Cnt'] = np.log(df['XMR / Tx per Second Cnt']).diff()
df['XMR / Mean Tx Fee (native units)'] = np.log(df['XMR / Mean Tx Fee (native units)']).diff()

# %%
#df = df.dropna()

# %%
df
# Out:
#             BTC / USD Denominated Closing Price  \
# Time
# 2009-01-03                                  NaN
# 2009-01-04                                  NaN
# 2009-01-05                                  NaN
# 2009-01-06                                  NaN
# 2009-01-07                                  NaN
# ...                                         ...
# 2023-03-09                            -0.064304
# 2023-03-10                            -0.005391
# 2023-03-11                             0.016893
# 2023-03-12                             0.069463
# 2023-03-13                             0.090431
#
#             BTC / Mean Tx Fee (native units)  BTC / Mean Hash Rate  \
# Time
# 2009-01-03                               NaN                   NaN
# 2009-01-04                               NaN                   NaN
# 2009-01-05                               NaN                   NaN
# 2009-01-06                               NaN                   NaN
# ...

# %%
BTG = df[['BTG / Mean Hash Rate','BTG / USD Denominated Closing Price','BTG / Tx per Second Cnt','BTG / Mean Tx Fee (native units)']]

# %%
ETH = df[['ETH / Mean Hash Rate','ETH / USD Denominated Closing Price','ETH / Tx per Second Cnt','ETH / Mean Tx Fee (native units)']]

# %%
ETC = df[['ETC / Mean Hash Rate','ETC / USD Denominated Closing Price','ETC / Tx per Second Cnt','ETC / Mean Tx Fee (native units)']]

# %%
BTG = BTG.dropna()

# %%
ETH = ETC.dropna()

# %%
ETC = ETC.dropna()

# %%
date_to_select = '2018-01-01'
selected_rows = BTG[BTG.index >= date_to_select]

# %%
selected_rows
# Out:
#             BTG / Mean Hash Rate  BTG / USD Denominated Closing Price  \
# Time
# 2018-01-01              0.072842                            -0.013922
# 2018-01-02             -0.031334                             0.059503
# 2018-01-03             -0.125223                            -0.040427
# 2018-01-04              0.084190                            -0.024680
# 2018-01-05             -0.104711                            -0.008415
# ...                          ...                                  ...
# 2023-03-09              0.029982                            -0.070812
# 2023-03-10             -0.009328                             0.005892
# 2023-03-11             -0.007964                            -0.009642
# 2023-03-12             -0.069107                             0.054061
# 2023-03-13              0.036104                             0.065253
#
#             BTG / Tx per Second Cnt  BTG / Mean Tx Fee (native units)
# Time
# ...

# %%
# select rows after a specific date
#date_to_select = '2021-01-01'
#selected_rows = df[df.index >= date_to_select]

# %%
df_weekly = selected_rows.resample('W').mean()

# %%
ETH_weekly = ETH.resample('W').mean()

# %%
df_monthly = selected_rows.resample('M').mean()

# %%
ETH_monthly = ETH.resample('M').mean()

# %%
ETH_monthly = ETH_monthly.dropna()

# %%
ETH_weekly = ETH_weekly.dropna()

# %%
import pandas as pd
import statsmodels.api as sm
from tabulate import tabulate

# create a VAR model with two lags
model = sm.tsa.VAR(ETH_weekly)
results = model.fit(6)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     17:32:55
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -29.4728
# Nobs:                     366.000    HQIC:                  -30.1153
# Log likelihood:           3611.32    FPE:                5.46294e-14
# AIC:                     -30.5391    Det(Omega_mle):     4.19414e-14
# --------------------------------------------------------------------
# Results for equation ETH / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.001437         0.000528            2.721           0.007
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from tabulate import tabulate

# create a VAR model with two lags
model = sm.tsa.VAR(df_weekly)
results = model.fit(6)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     17:59:48
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -23.7158
# Nobs:                     266.000    HQIC:                  -24.5217
# Log likelihood:           1923.62    FPE:                1.30695e-11
# AIC:                     -25.0630    Det(Omega_mle):     9.12461e-12
# --------------------------------------------------------------------
# Results for equation BTG / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                         -0.001040         0.001957           -0.531           0.595
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from tabulate import tabulate
# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(4)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     17:53:23
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -19.0714
# Nobs:                     131.000    HQIC:                  -19.3059
# Log likelihood:           921.292    FPE:                3.51565e-09
# AIC:                     -19.4665    Det(Omega_mle):     3.07817e-09
# --------------------------------------------------------------------
# Results for equation BTC / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.001150         0.000705            1.632           0.103
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# select a subset of the columns
cols = ['ETC / Mean Hash Rate','ETC / USD Denominated Closing Price','ETC / Tx per Second Cnt','ETC / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(5)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     17:07:26
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -25.7288
# Nobs:                     189.000    HQIC:                  -26.5859
# Log likelihood:           1578.80    FPE:                1.59226e-12
# AIC:                     -27.1695    Det(Omega_mle):     1.04468e-12
# --------------------------------------------------------------------
# Results for equation ETC / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.001750         0.001184            1.477           0.140
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# select a subset of the columns
cols = ['BTC / Mean Hash Rate','BTC / USD Denominated Closing Price','BTC / Tx per Second Cnt','BTC / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(8)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     17:07:26
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -28.3676
# Nobs:                     186.000    HQIC:                  -29.7291
# Log likelihood:           1927.39    FPE:                4.92611e-14
# AIC:                     -30.6568    Det(Omega_mle):     2.56318e-14
# --------------------------------------------------------------------
# Results for equation BTC / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.002707         0.001588            1.705           0.088
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# select a subset of the columns
cols = ['LTC / Mean Hash Rate','LTC / USD Denominated Closing Price','LTC / Tx per Second Cnt','LTC / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(2)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     13:43:45
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -30.6668
# Nobs:                     251.000    HQIC:                  -30.9690
# Log likelihood:           2523.53    FPE:                2.89752e-14
# AIC:                     -31.1725    Det(Omega_mle):     2.51668e-14
# --------------------------------------------------------------------
# Results for equation LTC / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.001164         0.000872            1.335           0.182
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# select a subset of the columns
cols = ['XMR / Mean Hash Rate','XMR / USD Denominated Closing Price','XMR / Tx per Second Cnt','XMR / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(2)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     13:43:46
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -27.6482
# Nobs:                     251.000    HQIC:                  -27.9504
# Log likelihood:           2144.69    FPE:                5.92918e-13
# AIC:                     -28.1538    Det(Omega_mle):     5.14986e-13
# --------------------------------------------------------------------
# Results for equation XMR / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.001331         0.001334            0.998           0.318
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# select a subset of the columns
cols = ['DOGE / Mean Hash Rate','DOGE / USD Denominated Closing Price','DOGE / Tx per Second Cnt','DOGE / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(2)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     13:43:46
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -29.6992
# Nobs:                     251.000    HQIC:                  -30.0013
# Log likelihood:           2402.09    FPE:                7.62565e-14
# AIC:                     -30.2048    Det(Omega_mle):     6.62336e-14
# --------------------------------------------------------------------
# Results for equation DOGE / Mean Hash Rate
# ...
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                           0.001262         0.000850            1.486           0.137
# ...

# %%
#loading the data from an excel file
import pandas as pd
df = pd.read_excel('Coin_Metrics_Network_Data_2023-03-14T12-53.xlsx', index_col=0) 
df.index = pd.to_datetime(df.index)
df
# Out:
#             ETH / USD Denominated Closing Price  \
# Time
# 2015-07-30                                  NaN
# 2015-07-31                                  NaN
# 2015-08-01                                  NaN
# 2015-08-02                                  NaN
# 2015-08-03                                  NaN
# ...                                         ...
# 2023-03-09                          1436.668908
# 2023-03-10                          1434.149219
# 2023-03-11                          1477.245618
# 2023-03-12                          1586.499928
# 2023-03-13                          1677.886561
#
#             ETH / Mean Tx Fee (native units)  ETH / Mean Hash Rate  \
# Time
# 2015-07-30                               NaN              0.027212
# 2015-07-31                               NaN              0.047934
# 2015-08-01                               NaN              0.054347
# 2015-08-02                               NaN              0.063287
# ...

# %%
df = df.dropna()

# %%
df['BCH / USD Denominated Closing Price'] = np.log(df['BCH / USD Denominated Closing Price']).diff()
df['BCH / Mean Hash Rate'] = np.log(df['BCH / Mean Hash Rate']).diff()
df['BCH / Tx per Second Cnt'] = np.log(df['BCH / Tx per Second Cnt']).diff()
df['BCH / Mean Tx Fee (native units)'] = np.log(df['BCH / Mean Tx Fee (native units)']).diff()
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_8315/2910888051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH / USD Denominated Closing Price'] = np.log(df['BCH / USD Denominated Closing Price']).diff()
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_8315/2910888051.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH / Mean Hash Rate'] = np.log(df['BCH / Mean Hash Rate']).diff()
# ...

# %%
df_weekly = df.resample('W').mean()

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# select a subset of the columns
cols = ['BCH / Mean Hash Rate','BCH / USD Denominated Closing Price','BCH / Tx per Second Cnt','BCH / Mean Tx Fee (native units)']
data_subset = df_weekly[cols]

# create a VAR model with two lags
model = sm.tsa.VAR(data_subset)
results = model.fit(2)

results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 03, Apr, 2023
# Time:                     13:49:59
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -24.0976
# Nobs:                     266.000    HQIC:                  -24.3878
# Log likelihood:           1795.74    FPE:                2.10835e-11
# AIC:                     -24.5826    Det(Omega_mle):     1.84561e-11
# --------------------------------------------------------------------
# Results for equation BCH / Mean Hash Rate
# ...
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          0.000365         0.002961            0.123           0.902
# ...

# %% [markdown]
# # Maximum Hash Rate

# %%
#Block Reward
df['ETC Block Reward'] = 5
cutoff_date = pd.to_datetime('2017-12-11')
df.loc[df.index > cutoff_date, 'ETC Block Reward'] = 4
cutoff_date = pd.to_datetime('2020-03-17')
df.loc[df.index > cutoff_date, 'ETC Block Reward'] = 3.2
cutoff_date = pd.to_datetime('2021-04-25')
df.loc[df.index > cutoff_date, 'ETC Block Reward'] = 2.56
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_8315/3090072792.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ETC Block Reward'] = 5
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_8315/3090072792.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df.index > cutoff_date, 'ETC Block Reward'] = 3.2

# %%
#Transaction Fees
df['ETC / Mean Tx Fee per Second'] = df['ETC / Mean Tx Fee (native units)']/df['ETC / Tx per Second Cnt']
df['ETC / Mean Tx Fee per Block'] = df['ETC / Mean Tx Fee per Second']*13
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ETC / Mean Tx Fee (native units)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#Cumulative Miner Revenue
df['ETC/SEC'] = (df['ETC Block Reward']+df['ETC / Mean Tx Fee per Block'])/13

# %%
df['Efficiency [Hash/J]'] = 0.3846153846*1000000
cutoff_date = pd.to_datetime('2016-08-04')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 0.4509685714*1000000
cutoff_date = pd.to_datetime('2017-12-07')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 0.46478125*1000000
cutoff_date = pd.to_datetime('2018-09-01')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 0.6666666667*1000000
cutoff_date = pd.to_datetime('2020-05-14')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 0.85*1000000
cutoff_date = pd.to_datetime('2020-12-01')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 0.8666666667*1000000
cutoff_date = pd.to_datetime('2021-11-01')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 2.083333333*1000000
cutoff_date = pd.to_datetime('2021-12-01')
df.loc[df.index > cutoff_date, 'Efficiency [Hash/J]'] = 2.166666667*1000000

# %%
df['Efficiency [J/Hash]'] = 1/(df['Efficiency [Hash/J]'])

# %%
df['ElectricityPrice'] = 0.05/3600000

# %%
#Profitability Threshold ETC
df['ETC Profatibilty Threshold [J/Hash]'] = (df['ETC / USD Denominated Closing Price'] * df['ETC/SEC']) /(df['ETC / Mean Hash Rate']*1000000000000*df['ElectricityPrice'])

# %%
df['ETC / Max Hash Rate'] = (df['ETC/SEC']*df['ETC / USD Denominated Closing Price'])/(df['ElectricityPrice']*df['Efficiency [J/Hash]'])*(1/1000000000000)

# %%
df['Extra'] = 0
cutoff_date = pd.to_datetime('2022-09-14')
df.loc[df.index > cutoff_date, 'Extra'] = 700

# %%
df['ETC / Mean Hash Rate'] = df['ETC / Mean Hash Rate']+df['Extra']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

start_date = pd.Timestamp('2021-01-01')
end_date = pd.Timestamp('2022-12-31')
sns.set(style="darkgrid")
ax = df.loc[start_date:end_date, ['ETC / Max Hash Rate','ETC / Mean Hash Rate']].plot(figsize=(10,6))
# add vertical line at Merge
#ax.axvline(x='2022-09-15', color='green', linestyle='-', linewidth=2)

# set the labels and title
ax.set_title('Hash Rates of ETH & ETC', fontsize=20, fontweight='bold')
ax.set_xlabel('Date', fontsize=16)
ax.set_ylabel('Hashrate in TH/s', fontsize=16)
ax.legend(fontsize=14)
ax.tick_params(axis='both', labelsize=12)
#plt.savefig('myplot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Block Reward
df['BCH Block Reward'] = 12.5
cutoff_date = pd.to_datetime('2020-04-08')
df.loc[df.index > cutoff_date, 'BCH Block Reward'] = 6.25

# %%
df['ElectricityPrice'] = 0.05/3600000
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_19805/980764329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ElectricityPrice'] = 0.05/3600000

# %%
#Transaction Fees
df['BCH / Mean Tx Fee per Second'] = df['BCH / Mean Tx Fee (native units)']/df['BCH / Tx per Second Cnt']
df['BCH / Mean Tx Fee per Block'] = df['BCH / Mean Tx Fee per Second']*600
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_19805/10644203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH / Mean Tx Fee per Second'] = df['BCH / Mean Tx Fee (native units)']/df['BCH / Tx per Second Cnt']
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_19805/10644203.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH / Mean Tx Fee per Block'] = df['BCH / Mean Tx Fee per Second']*600

# %%
#Cumulative Miner Revenue
df['BCH/SEC'] = (df['BCH Block Reward']+df['BCH / Mean Tx Fee per Block'])/600
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_19805/835695588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH/SEC'] = (df['BCH Block Reward']+df['BCH / Mean Tx Fee per Block'])/600

# %%
#Profitability Threshold ETC
df['BCH Profatibilty Threshold [J/Hash]'] = (df['BCH / USD Denominated Closing Price'] * df['BCH/SEC']) /(df['BCH / Mean Hash Rate']*1000000000000*df['ElectricityPrice'])
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_19805/3235851709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BCH Profatibilty Threshold [J/Hash]'] = (df['BCH / USD Denominated Closing Price'] * df['BCH/SEC']) /(df['BCH / Mean Hash Rate']*1000000000000*df['ElectricityPrice'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

start_date = pd.Timestamp('2021-01-01')
end_date = pd.Timestamp('2022-12-31')
sns.set(style="darkgrid")
ax = df.loc[start_date:end_date, ['BCH Profatibilty Threshold [J/Hash]']].plot(figsize=(10,6),logy=True)
# add vertical line at Merge
#ax.axvline(x='2022-09-15', color='green', linestyle='-', linewidth=2)

# set the labels and title
ax.set_title('Hash Rates of ETH & ETC', fontsize=20, fontweight='bold')
ax.set_xlabel('Date', fontsize=16)
ax.set_ylabel('Hashrate in TH/s', fontsize=16)
ax.legend(fontsize=14)
ax.tick_params(axis='both', labelsize=12)
#plt.savefig('myplot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# January 3, 2009: The first Bitcoin block (the "genesis block") is mined, with a reward of 50 BTC.
# November 28, 2012: The first halving event occurs, reducing the block reward from 50 BTC to 25 BTC.
# July 9, 2016: The second halving event occurs, reducing the block reward from 25 BTC to 12.5 BTC.
# December 17, 2017: Bitcoin reaches an all-time high price of almost $20,000 per BTC.
# May 11, 2020: The third halving event occurs, reducing the block reward from 12.5 BTC to 6.25 BTC.

# %%
#Block Reward
df['BTC Block Reward'] = 50
cutoff_date = pd.to_datetime('2012-11-28')
df.loc[df.index > cutoff_date, 'BCH Block Reward'] = 25
cutoff_date = pd.to_datetime('2016-07-09')
df.loc[df.index > cutoff_date, 'BCH Block Reward'] = 12.5
cutoff_date = pd.to_datetime('2020-05-11')
df.loc[df.index > cutoff_date, 'BCH Block Reward'] = 6.25

# %%
df['ElectricityPrice'] = 0.05/3600000

# %%
#Transaction Fees
df['BTC / Mean Tx Fee per Second'] = df['BTC / Mean Tx Fee (native units)']/df['BTC / Tx per Second Cnt']
df['BTC / Mean Tx Fee per Block'] = df['BTC / Mean Tx Fee per Second']*600

# %%
#Cumulative Miner Revenue
df['BTC/SEC'] = (df['BTC Block Reward']+df['BTC / Mean Tx Fee per Block'])/600

# %%
#Profitability Threshold ETC
df['BTC Profatibilty Threshold [J/Hash]'] = (df['BTC / USD Denominated Closing Price'] * df['BTC/SEC']) /(df['BTC / Mean Hash Rate']*1000000000000*df['ElectricityPrice'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

start_date = pd.Timestamp('2021-01-01')
end_date = pd.Timestamp('2022-12-31')
sns.set(style="darkgrid")
ax = df.loc[start_date:end_date, ['BTC Profatibilty Threshold [J/Hash]']].plot(figsize=(10,6),logy=True)
# add vertical line at Merge
#ax.axvline(x='2022-09-15', color='green', linestyle='-', linewidth=2)

# set the labels and title
ax.set_title('Hash Rates of ETH & ETC', fontsize=20, fontweight='bold')
ax.set_xlabel('Date', fontsize=16)
ax.set_ylabel('Hashrate in TH/s', fontsize=16)
ax.legend(fontsize=14)
ax.tick_params(axis='both', labelsize=12)

# set the background color to transparent
ax.patch.set_alpha(0.0)

# show the plot
plt.show()

# %%
29.5/1000000000000
# Out:
# 2.95e-11
