# %%
import pandas as pd
import numpy as np
# Load the Excel file into a Pandas DataFrame
df = pd.read_excel('Chart-Thu Apr 27 2023 (1).xlsx', sheet_name='Sheet1',index_col='Time', parse_dates=True)

# Display the first 5 rows of the DataFrame
df = df.dropna()
df
# Out:
#             BTC / Addresses, active, count  \
# Time
# 2010-07-18                             860
# 2010-07-19                             929
# 2010-07-20                             936
# 2010-07-21                             784
# 2010-07-22                             594
# ...                                    ...
# 2023-04-22                          914896
# 2023-04-23                          840711
# 2023-04-24                          998948
# 2023-04-25                          895988
# 2023-04-26                          893248
#
#             BTC / Capitalization, market, current supply, USD
# Time
# 2010-07-18                                       2.959592e+05
# 2010-07-19                                       2.792852e+05
# 2010-07-20                                       2.590004e+05
# 2010-07-21                                       2.752665e+05
# 2010-07-22                                       2.037496e+05
# ...

# %%
df['MetcalfeLaw'] = df['BTC / Addresses, active, count']**2-df['BTC / Addresses, active, count']

# %%
df_monthly_mean1 = df.resample('M').mean()
df_monthly_mean1['BTC / Addresses, active, count'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_monthly_mean['BTC / Capitalization, market, current supply, USD'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/136782269.py in <module>
# ----> 1 df_monthly_mean['BTC / Capitalization, market, current supply, USD'].plot()
#
# NameError: name 'df_monthly_mean' is not defined

# %%
df_log = pd.DataFrame(np.log(df_monthly_mean), columns=df_monthly_mean.columns, index=df_monthly_mean.index)

# %%
df_log.plot()

# %% [markdown]
# # Facebook

# %%
df = pd.read_csv('META.csv',index_col='Date', parse_dates=True)

# %%
df = df['Close']

# %%
df1 = pd.read_excel('facebook.xlsx')

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
# Date
# 2012-06-01     31.100000
# 2012-07-01     21.709999
# 2012-08-01     18.059999
# 2012-09-01     21.660000
# 2012-10-01     21.110001
#                  ...
# 2023-01-01    148.970001
# 2023-02-01    174.940002
# 2023-03-01    211.940002
# 2023-04-01    209.399994
# 2023-04-26    209.399994
# Name: Close, Length: 132, dtype: float64

# %%
df_quarterly_mean = df.resample('Q').mean()

# Display the aggregated DataFrame
df_quarterly_mean
# Out:
# Date
# 2012-06-30     31.100000
# 2012-09-30     20.476666
# 2012-12-31     25.243334
# 2013-03-31     27.936667
# 2013-06-30     25.666666
# 2013-09-30     42.773333
# 2013-12-31     50.623333
# 2014-03-31     63.756667
# 2014-06-30     63.456666
# 2014-09-30     75.503334
# 2014-12-31     76.903331
# 2015-03-31     79.033335
# 2015-06-30     81.243332
# 2015-09-30     91.113335
# 2015-12-31    103.623334
# 2016-03-31    111.076665
# 2016-06-30    116.890000
# 2016-09-30    126.110003
# 2016-12-31    121.486669
# 2017-03-31    135.970001
# 2017-06-30    150.896668
# 2017-09-30    170.696665
# 2017-12-31    177.899999
# 2018-03-31    175.000000
# 2018-06-30    186.033335
# 2018-09-30    170.923335
# 2018-12-31    141.163330
# 2019-03-31    164.943334
# 2019-06-30    187.956665
# 2019-09-30    185.993332
# 2019-12-31    199.513331
# 2020-03-31    187.060003
# 2020-06-30    218.956670
# 2020-09-30    269.590001
# 2020-12-31    271.079997
# 2021-03-31    270.159994
# ...

# %%
# Generate a quarterly datetime index
start_date = pd.to_datetime('2008-12-31')
end_date = pd.to_datetime('2022-12-31')
idx = pd.date_range(start=start_date, end=end_date, freq='Q')

# Create a DataFrame with the quarterly datetime index
df = pd.DataFrame()
df['Users'] = df1['Users']

# %%
df
# Out:
#     Users
# 0     100
# 1     197
# 2     242
# 3     305
# 4     360
# 5     431
# 6     482
# 7     550
# 8     608
# 9     680
# 10    739
# 11    800
# 12    845
# 13    901
# 14    955
# 15   1007
# 16   1056
# 17   1110
# 18   1155
# 19   1189
# 20   1228
# 21   1276
# 22   1317
# 23   1350
# 24   1393
# 25   1441
# 26   1490
# 27   1545
# 28   1591
# 29   1654
# 30   1712
# 31   1788
# 32   1860
# 33   1936
# 34   2006
# 35   2072
# 36   2129
# 37   2196
# 38   2234
# 39   2271
# 40   2320
# 41   2375
# 42   2414
# 43   2449
# 44   2498
# 45   2603
# 46   2701
# 47   2740
# 48   2797
# 49   2853
# 50   2895
# 51   2910
# 52   2912
# 53   2936
# 54   2934
# 55   2958
# 56   2963

# %%
df.index = idx

# %%
df
# Out:
#             Users
# 2008-12-31    100
# 2009-03-31    197
# 2009-06-30    242
# 2009-09-30    305
# 2009-12-31    360
# 2010-03-31    431
# 2010-06-30    482
# 2010-09-30    550
# 2010-12-31    608
# 2011-03-31    680
# 2011-06-30    739
# 2011-09-30    800
# 2011-12-31    845
# 2012-03-31    901
# 2012-06-30    955
# 2012-09-30   1007
# 2012-12-31   1056
# 2013-03-31   1110
# 2013-06-30   1155
# 2013-09-30   1189
# 2013-12-31   1228
# 2014-03-31   1276
# 2014-06-30   1317
# 2014-09-30   1350
# 2014-12-31   1393
# 2015-03-31   1441
# 2015-06-30   1490
# 2015-09-30   1545
# 2015-12-31   1591
# 2016-03-31   1654
# 2016-06-30   1712
# 2016-09-30   1788
# 2016-12-31   1860
# 2017-03-31   1936
# 2017-06-30   2006
# 2017-09-30   2072
# 2017-12-31   2129
# 2018-03-31   2196
# 2018-06-30   2234
# 2018-09-30   2271
# 2018-12-31   2320
# 2019-03-31   2375
# 2019-06-30   2414
# 2019-09-30   2449
# 2019-12-31   2498
# 2020-03-31   2603
# 2020-06-30   2701
# 2020-09-30   2740
# 2020-12-31   2797
# ...

# %%
df = df.join(df_quarterly_mean)

# %%
df = df.dropna()

# %%
df = df[['Users', 'Close']]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df_log = pd.DataFrame(np.log(df), columns=df.columns, index=df.index)

# %%
import statsmodels.api as sm
X = df_log[['Users']]
y = df_log['Close']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     278.2
# Date:                Sat, 29 Apr 2023   Prob (F-statistic):           7.08e-20
# Time:                        13:24:02   Log-Likelihood:                -3.8876
# No. Observations:                  43   AIC:                             11.78
# Df Residuals:                      41   BIC:                             15.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.1000      0.892    -11.320      0.000     -11.902      -8.298
# ...

# %%
df_log['Model'] = -10.1000 + 1.9672*df_log['Users']

# %%
df_log.plot()
# Out:
# <AxesSubplot:>

# %%
df = np.exp(df_log)
df[['Model','Close']].plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

# Load the Excel file into a Pandas DataFrame
df = pd.read_excel('Chart-Thu Apr 27 2023 (2).xlsx', sheet_name='Sheet1',index_col='Time', parse_dates=True)

# Display the first 5 rows of the DataFrame
df = df.dropna()
# Cut off all data before January 1, 2017
df = df.loc['2017-01-01':]
df

# %%
df['MetcalfesLaw'] = df['ETH / Addresses, active, count']**2-df['ETH / Addresses, active, count']

# %%
df_log = pd.DataFrame(np.log(df), columns=df.columns, index=df.index)

# %%
df_log.plot()

# %%
df_M2 = pd.read_excel('WM2NS.xlsx',index_col='observation_date', parse_dates=True)

# %%
df_M2
# Out:
#                     WM2NS
# observation_date
# 2007-01-08         7145.1
# 2007-01-15         7138.0
# 2007-01-22         7083.9
# 2007-01-29         7029.6
# 2007-02-05         7096.4
# ...                   ...
# 2023-03-06        21128.5
# 2023-03-13        21114.7
# 2023-03-20        20950.6
# 2023-03-27        20823.0
# 2023-04-03        20877.6
#
# [848 rows x 1 columns]

# %%
start_date = pd.to_datetime('2007-01-14')
end_date = pd.to_datetime('2023-04-09')
idx = pd.date_range(start=start_date, end=end_date, freq='W')

# %%
df_M2.index = idx

# %%
df_M2
# Out:
#               WM2NS
# 2007-01-14   7145.1
# 2007-01-21   7138.0
# 2007-01-28   7083.9
# 2007-02-04   7029.6
# 2007-02-11   7096.4
# ...             ...
# 2023-03-12  21128.5
# 2023-03-19  21114.7
# 2023-03-26  20950.6
# 2023-04-02  20823.0
# 2023-04-09  20877.6
#
# [848 rows x 1 columns]

# %%
df_M2 = df_M2.resample('M').mean()

# %%
df_monthly_mean

# %%
df_monthly_mean1

# %%
df = df_monthly_mean.join(df_monthly_mean1)

# %%
df

# %%
df.plot()

# %%
df_log = pd.DataFrame(np.log(df), columns=df.columns, index=df.index)

# %%
df_log.plot()

# %%
df_log['diff'] = df_log['WM2NS'] - df_log['WM2NS'].shift(12)

# %%
df_log['diff'] = df_log['diff']+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_log['Model'] = df_log['diff']*df_log['MetcalfeLaw']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_log[['Model','BTC / Capitalization, market, current supply, USD','MetcalfeLaw']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/674345420.py in <module>
# ----> 1 df_log[['Model','BTC / Capitalization, market, current supply, USD','MetcalfeLaw']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %% [markdown]
# # Bitcoin

# %%
import pandas as pd
import numpy as np
# Load the Excel file into a Pandas DataFrame
df = pd.read_excel('BTCGMI.xlsx', sheet_name='Sheet1',index_col='Time', parse_dates=True)

# Display the first 5 rows of the DataFrame
df = df.dropna()
df
# Out:
#             BTC / Addresses, active, count  \
# Time
# 2010-07-18                             860
# 2010-07-19                             929
# 2010-07-20                             936
# 2010-07-21                             784
# 2010-07-22                             594
# ...                                    ...
# 2023-04-22                          914896
# 2023-04-23                          840711
# 2023-04-24                          998948
# 2023-04-25                          895988
# 2023-04-26                          893248
#
#             BTC / Capitalization, market, current supply, USD  \
# Time
# 2010-07-18                                       2.959592e+05
# 2010-07-19                                       2.792852e+05
# 2010-07-20                                       2.590004e+05
# 2010-07-21                                       2.752665e+05
# 2010-07-22                                       2.037496e+05
# ...

# %%
df = df.resample('W').mean()

# %%
df = df.loc[:'2023-04-03']

# %%
df['BTC / Addresses, active, count'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
# Assuming your DataFrame is named df and has a datetime index
df.index = df.index - pd.DateOffset(years=2)

# %%
df['BTC / Capitalization, market, current supply, USD'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df = df.join(df_M2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/3202630145.py in <module>
# ----> 1 df = df.join(df_M2)
#
# NameError: name 'df_M2' is not defined

# %%
df[['BTC / Capitalization, market, current supply, USD','WM2NS']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/3707472534.py in <module>
# ----> 1 df[['BTC / Capitalization, market, current supply, USD','WM2NS']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
df['BTC / Addresses, active, count_2']= df['BTC / Addresses, active, count']**2

# %%
df_log = pd.DataFrame(np.log(df), columns=df.columns, index=df.index)

# %%
df_log
# Out:
#             BTC / Addresses, active, count  \
# Time
# 2008-07-18                        6.756932
# 2008-07-25                        6.905896
# 2008-08-01                        6.552304
# 2008-08-08                        6.547195
# 2008-08-15                        6.472567
# ...                                    ...
# 2021-03-05                       13.811128
# 2021-03-12                       13.765418
# 2021-03-19                       13.786203
# 2021-03-26                       13.739925
# 2021-04-02                       13.834557
#
#             BTC / Capitalization, market, current supply, USD  \
# Time
# 2008-07-18                                          12.597977
# 2008-07-25                                          12.338233
# 2008-08-01                                          12.309463
# 2008-08-08                                          12.289738
# 2008-08-15                                          12.429293
# ...

# %%
df_train =  df_log.loc['2011-01-01':'2020-12-31']

# %%
import statsmodels.api as sm
X = df_train[['BTC / Addresses, active, count', 'BTC / Transactions, transfers, value, mean, USD','WM2NS']]
y = df_train['BTC / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/2602713527.py in <module>
#       1 import statsmodels.api as sm
# ----> 2 X = df_train[['BTC / Addresses, active, count', 'BTC / Transactions, transfers, value, mean, USD','WM2NS']]
#       3 y = df_train['BTC / Capitalization, market, current supply, USD']
#       4
#       5 # Add a constant to the independent variables to include an intercept in the model
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ...

# %%
df_log['Model']=-32.6596+0.8500*df_log['BTC / Addresses, active, count']+0.6824 *df_log['BTC / Transactions, transfers, value, mean, USD']+4.2031*df_log['WM2NS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WM2NS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_log['Model_Low']= -26.330+1.021*df_log['BTC / Addresses, active, count']+0.480*df_log['BTC / Transactions, transfers, value, mean, USD']+2.721*df_log['WM2NS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WM2NS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_log['Model_High'] = -20.639+ 1.123*df_log['BTC / Addresses, active, count']+0.596*df_log['BTC / Transactions, transfers, value, mean, USD']+3.388*df_log['WM2NS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WM2NS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#df_log = df_log.resample('Q').mean()

# %%
df_log[['Model','BTC / Capitalization, market, current supply, USD' ]].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/3010222251.py in <module>
# ----> 1 df_log[['Model','BTC / Capitalization, market, current supply, USD' ]].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
df = np.exp(df_log)
df[['Model','BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/1134451200.py in <module>
#       1 df = np.exp(df_log)
# ----> 2 df[['Model','BTC / Capitalization, market, current supply, USD']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
df = df.loc['2021-01-01':]

# %%
df[['Model','BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/574191750.py in <module>
# ----> 1 df[['Model','BTC / Capitalization, market, current supply, USD']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
df_FCI = pd.read_csv('nfci-data-series-csv.csv',index_col='Friday_of_Week', parse_dates=True)

# %%
df_FCI = df_FCI.loc['2010-08-01':]

# %%
df_FCI
# Out:
#                     NFCI     ANFCI      Risk    Credit  Leverage  \
# Friday_of_Week
# 2010-08-06     -0.263028 -0.315793 -0.219532  0.033965  0.145911
# 2010-08-13     -0.266052 -0.305332 -0.232730  0.033008  0.139140
# 2010-08-20     -0.264656 -0.286477 -0.239745  0.034189  0.134048
# 2010-08-27     -0.263672 -0.273917 -0.244555  0.034559  0.131237
# 2010-09-03     -0.267616 -0.277475 -0.250667  0.031059  0.131367
# ...                  ...       ...       ...       ...       ...
# 2023-03-24     -0.201256 -0.078544 -0.245364  0.086124  0.553878
# 2023-03-31     -0.208664 -0.100462 -0.254385  0.083086  0.623545
# 2023-04-07     -0.229983 -0.149801 -0.274693  0.073189  0.683668
# 2023-04-14     -0.263387 -0.214166 -0.304930  0.058403  0.732359
# 2023-04-21     -0.302179 -0.275936 -0.339681  0.040986  0.769893
#
#                 Nonfinancial_Leverage
# Friday_of_Week
# 2010-08-06                  -0.948908
# 2010-08-13                  -0.964662
# ...

# %%
start_date = pd.to_datetime('2010-08-08')
end_date = pd.to_datetime('2023-04-23')
idx = pd.date_range(start=start_date, end=end_date, freq='W')

# %%
df_FCI.index = idx

# %%
df_log = df_log.join(df_FCI)

# %%
df_log
# Out:
#             BTC / Addresses, active, count  \
# Time
# 2008-07-18                        6.756932
# 2008-07-25                        6.905896
# 2008-08-01                        6.552304
# 2008-08-08                        6.547195
# 2008-08-15                        6.472567
# ...                                    ...
# 2021-03-05                       13.811128
# 2021-03-12                       13.765418
# 2021-03-19                       13.786203
# 2021-03-26                       13.739925
# 2021-04-02                       13.834557
#
#             BTC / Capitalization, market, current supply, USD  \
# Time
# 2008-07-18                                          12.597977
# 2008-07-25                                          12.338233
# 2008-08-01                                          12.309463
# 2008-08-08                                          12.289738
# 2008-08-15                                          12.429293
# ...

# %%
df_log = df_log.dropna()

# %%
df_log
# Out:
# Empty DataFrame
# Columns: [BTC / Addresses, active, count, BTC / Capitalization, market, current supply, USD, BTC / Transactions, transfers, value, mean, USD, BTC / Transactions, count, per second, BTC / Addresses, active, count_2, NFCI, ANFCI, Risk, Credit, Leverage, Nonfinancial_Leverage]
# Index: []

# %%
df_log[['BTC / Capitalization, market, current supply, USD','NFCI']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_train =  df_log.loc['2011-01-01':'2022-12-31']

# %%
import statsmodels.api as sm
X = df_log[['BTC / Addresses, active, count', 'BTC / Transactions, transfers, value, mean, USD','NFCI']]
y = df_log['BTC / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     BTC / Capitalization, market, current supply, USD   R-squared:                       0.968
# Model:                                                           OLS   Adj. R-squared:                  0.968
# Method:                                                Least Squares   F-statistic:                     6617.
# Date:                                               Sat, 29 Apr 2023   Prob (F-statistic):               0.00
# Time:                                                       09:55:23   Log-Likelihood:                -674.62
# No. Observations:                                                664   AIC:                             1357.
# Df Residuals:                                                    660   BIC:                             1375.
# Df Model:                                                          3
# Covariance Type:                                           nonrobust
# ...

# %%
df_log['Model'] = 2.0942 + 1.1242*df_log['BTC / Addresses, active, count']+0.855*df_log['BTC / Transactions, transfers, value, mean, USD']-0.6815*df_log['NFCI']
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/4216959044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_log['Model'] = 2.0942 + 1.1242*df_log['BTC / Addresses, active, count']+0.855*df_log['BTC / Transactions, transfers, value, mean, USD']-0.6815*df_log['NFCI']

# %%
df_log[['Model', 'BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_test =  df_log.loc['2023-01-01':]

# %%
df_test[['Model', 'BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/2469702541.py in <module>
# ----> 1 df_test[['Model', 'BTC / Capitalization, market, current supply, USD']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
df_test_exp = np.exp(df_test)
df_test_exp[['Model','BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/3142382648.py in <module>
#       1 df_test_exp = np.exp(df_test)
# ----> 2 df_test_exp[['Model','BTC / Capitalization, market, current supply, USD']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
# Define the independent variables (X) and the dependent variable (y)
X = df_log[['BTC / Addresses, active, count', 'BTC / Transactions, transfers, value, mean, USD','NFCI','WM2NS']]
y = df_log['BTC / Capitalization, market, current supply, USD']

# Define the size of the rolling window
window_size = 52

# Loop through the rolling window to fit the regression model and make predictions
predictions = []
for i in range(window_size, len(df_log)):
    # Get the data in the current window
    X_window = X.loc[df_log.index[i-window_size+1]:df_log.index[i]]

    # Define the dependent variable in the current window
    y_window = y.loc[df_log.index[i-window_size+1]:df_log.index[i]]

    # Add a constant to the independent variables to include an intercept in the model
    X_window = sm.add_constant(X_window)

    # Fit the multivariate regression model using ordinary least squares (OLS)
    model = sm.OLS(y_window, X_window).fit()

    # Make a prediction for the next value in the time series
    next_X = [1] + list(X.iloc[i])
    next_prediction = model.predict(next_X)
    predictions.append(next_prediction[0])

# Add the predictions to the DataFrame
df_log['predictions'] = [None] * window_size + predictions

df_log[['predictions', 'BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/1862011330.py in <module>
#       1 # Define the independent variables (X) and the dependent variable (y)
# ----> 2 X = df_log[['BTC / Addresses, active, count', 'BTC / Transactions, transfers, value, mean, USD','NFCI','WM2NS']]
#       3 y = df_log['BTC / Capitalization, market, current supply, USD']
#       4
#       5 # Define the size of the rolling window
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ...

# %%
df_exp = np.exp(df_log)
df_exp[['Model','BTC / Capitalization, market, current supply, USD']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_1495/3906200248.py in <module>
#       1 df_exp = np.exp(df_log)
# ----> 2 df_exp[['Model','BTC / Capitalization, market, current supply, USD']].plot()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %% [markdown]
# # Amazon

# %%
df_AMZN = pd.read_csv('AMZN.csv',index_col='Date', parse_dates=True)

# %%
df_AMZN
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...                ...         ...         ...         ...         ...
# 2023-04-24  107.660004  109.230003  105.070000  106.209999  106.209999
# 2023-04-25  104.910004  105.449997  102.449997  102.570000  102.570000
# 2023-04-26  105.040001  106.620003  104.099998  104.980003  104.980003
# 2023-04-27  108.160004  110.860001  106.800003  109.820000  109.820000
# 2023-04-28  107.730003  109.480003  104.330002  105.449997  105.449997
#
#                 Volume
# Date
# 1997-05-15  1443120000
# 1997-05-16   294000000
# 1997-05-19   122136000
# ...

# %%
df_AMZN['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Compute the yearly averages
yearly_averages = df_AMZN.resample('Y').mean()

# %%
yearly_averages =  yearly_averages.loc[:'2022-12-31']

# %%
yearly_averages['Sales'] = [147758000, 609996000, 1639839000, 2761983000,3122433000, 3932936000, 5263699000, 6921124000, 8490000000, 10711000000, 14835000000, 19166000000, 24509000000,34204000000, 48077000000, 61093000000, 74452000000,  88988000000 , 107006000000,  135987000000 , 177866000000, 232887000000,309475500000 ,386064000000, 469822000000, 513983000000 ]

# %%
yearly_averages
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-12-31    0.155724    0.161497    0.150431    0.156320    0.156320
# 1998-12-31    0.777548    0.811660    0.749908    0.783056    0.783056
# 1999-12-31    3.470436    3.601638    3.317595    3.453116    3.453116
# 2000-12-31    2.330115    2.426299    2.230878    2.326683    2.326683
# 2001-12-31    0.613213    0.637426    0.585813    0.610021    0.610021
# 2002-12-31    0.820317    0.845905    0.800587    0.824206    0.824206
# 2003-12-31    1.880345    1.915065    1.850016    1.887069    1.887069
# 2004-12-31    2.177875    2.216688    2.141812    2.178262    2.178262
# 2005-12-31    1.991020    2.019069    1.969409    1.994855    1.994855
# 2006-12-31    1.793612    1.820769    1.768171    1.795466    1.795466
# 2007-12-31    3.355741    3.407827    3.305508    3.361474    3.361474
# 2008-12-31    3.491953    3.588350    3.401854    3.494002    3.494002
# ...

# %%
yearly_averages_log = pd.DataFrame(np.log(yearly_averages), columns=yearly_averages.columns, index=yearly_averages.index)

# %%
import statsmodels.api as sm
X = yearly_averages_log[['Sales']]
y = yearly_averages_log['Close']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     246.1
# Date:                Sat, 29 Apr 2023   Prob (F-statistic):           4.08e-14
# Time:                        13:27:05   Log-Likelihood:                -21.318
# No. Observations:                  26   AIC:                             46.64
# Df Residuals:                      24   BIC:                             49.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -17.9107      1.275    -14.044      0.000     -20.543     -15.279
# ...

# %%
yearly_averages_log['Model'] = -17.9107+0.8330*yearly_averages_log['Sales']

# %%
yearly_averages_log[['Model','Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
yearly_averages['Sales/Sales2001']= yearly_averages['Sales']/3122433000
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/984390544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_averages['Sales/Sales2001']= yearly_averages['Sales']/3122433000

# %%
yearly_averages[['Close','Sales/Sales2001']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_bubble =  df_AMZN.loc[:'2002-01-01']

# %%
df_bubble['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['BTC / Capitalization, market, current supply, USD'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df['BTCPrice']= df['BTC / Capitalization, market, current supply, USD']/(19000000*10000)

# %%
df['BTCPrice'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_MSFT = pd.read_csv('MSFT.csv',index_col='Date', parse_dates=True)

# %%
df_bubble1 =  df_MSFT.loc[:'2009-01-01']

# %%
df_bubble1['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Cardano

# %%
df_CAR = pd.read_excel('Chart-Sat Apr 29 2023.xlsx',index_col='Time', parse_dates=True)

# %%
df_CAR = df_CAR.dropna()

# %%
df_CAR_log
# Out:
#             ADA / Price, USD  ADA / Addresses, active, count  \
# Time
# 2017-12-03         -2.026495                        8.465771
# 2017-12-10         -2.123027                        8.571448
# 2017-12-17         -1.523887                        9.119996
# 2017-12-24         -0.772488                        9.582648
# 2017-12-31         -0.690108                        9.162203
# ...                      ...                             ...
# 2023-03-26         -1.027898                       10.863816
# 2023-04-02         -0.973294                       10.857950
# 2023-04-09         -0.948288                       10.740415
# 2023-04-16         -0.857539                       10.934762
# 2023-04-23         -0.896398                       11.008763
#
#             ADA / Transactions, count, per second  \
# Time
# 2017-12-03                              -3.585090
# 2017-12-10                              -3.452105
# 2017-12-17                              -2.920821
# ...

# %%
df_CAR_log = pd.DataFrame(np.log(df_CAR), columns=df_CAR.columns, index=df_CAR.index)

# %%
import statsmodels.api as sm
X = df_CAR_log[['ADA / Addresses, active, count','ADA / Transactions, transfers, value, mean, USD' ]]
y = df_CAR_log['ADA / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     ADA / Capitalization, market, current supply, USD   R-squared:                       0.859
# Model:                                                           OLS   Adj. R-squared:                  0.859
# Method:                                                Least Squares   F-statistic:                     6001.
# Date:                                               Mon, 01 May 2023   Prob (F-statistic):               0.00
# Time:                                                       15:03:33   Log-Likelihood:                -1425.7
# No. Observations:                                               1975   AIC:                             2857.
# Df Residuals:                                                   1972   BIC:                             2874.
# Df Model:                                                          2
# Covariance Type:                                           nonrobust
# ...

# %%
df_CAR_log['Model'] = 10.8752 +  0.8286*df_CAR_log['ADA / Addresses, active, count' ]+ 0.3393*df_CAR_log['ADA / Transactions, transfers, value, mean, USD' ]

# %%
df_CAR_log[['Model','ADA / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_CAR_log = df_CAR_log.resample('W').mean()

# %%
df_CAR_log
# Out:
#             ADA / Price, USD  ADA / Addresses, active, count  \
# Time
# 2017-12-03         -2.026495                        8.465771
# 2017-12-10         -2.123027                        8.571448
# 2017-12-17         -1.523887                        9.119996
# 2017-12-24         -0.772488                        9.582648
# 2017-12-31         -0.690108                        9.162203
# ...                      ...                             ...
# 2023-04-02         -0.973294                       10.857950
# 2023-04-09         -0.948288                       10.740415
# 2023-04-16         -0.857539                       10.934762
# 2023-04-23         -0.896398                       11.008763
# 2023-04-30         -0.919923                       10.837213
#
#             ADA / Transactions, count, per second  \
# Time
# 2017-12-03                              -3.585090
# 2017-12-10                              -3.452105
# 2017-12-17                              -2.920821
# ...

# %%
df_CAR_log = df_CAR_log.join(df_FCI)

# %%
df_CAR_log= df_CAR_log.dropna()

# %%
import statsmodels.api as sm
X = df_CAR_log[['ADA / Addresses, active, count','ADA / Transactions, transfers, value, mean, USD' ,'NFCI']]
y = df_CAR_log['ADA / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     ADA / Capitalization, market, current supply, USD   R-squared:                       0.913
# Model:                                                           OLS   Adj. R-squared:                  0.912
# Method:                                                Least Squares   F-statistic:                     975.5
# Date:                                               Mon, 01 May 2023   Prob (F-statistic):          3.35e-147
# Time:                                                       15:03:36   Log-Likelihood:                -134.61
# No. Observations:                                                282   AIC:                             277.2
# Df Residuals:                                                    278   BIC:                             291.8
# Df Model:                                                          3
# Covariance Type:                                           nonrobust
# ...

# %%
df_CAR_log['Model'] = 10.2837 +  0.8524*df_CAR_log['ADA / Addresses, active, count' ]+ 0.3261*df_CAR_log['ADA / Transactions, transfers, value, mean, USD' ]-1.0719*df_CAR_log['NFCI' ]

# %%
df_CAR_log[['Model','ADA / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df_CAR_log.index, df_CAR_log[['Model','ADA / Capitalization, market, current supply, USD']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %% [markdown]
# # Ethereum

# %%
df_ETH = pd.read_excel('Chart-Sat Apr 29 2023 (1).xlsx',index_col='Time', parse_dates=True)

# %%
df_ETH = df_ETH.dropna()

# %%
df_ETH_log = pd.DataFrame(np.log(df_ETH), columns=df_ETH.columns, index=df_ETH.index)

# %%
df_ETH_log = df_ETH_log.resample('W').mean()

# %%
df_ETH_log = df_ETH_log.join(df_FCI)

# %%
df_ETH_log= df_ETH_log.dropna()

# %%
import statsmodels.api as sm
X = df_ETH_log[['ETH / Addresses, active, count','ETH / Transactions, transfers, value, mean, USD' ]]
y = df_ETH_log['ETH / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     ETH / Capitalization, market, current supply, USD   R-squared:                       0.924
# Model:                                                           OLS   Adj. R-squared:                  0.923
# Method:                                                Least Squares   F-statistic:                     2416.
# Date:                                               Mon, 01 May 2023   Prob (F-statistic):          4.85e-224
# Time:                                                       15:02:32   Log-Likelihood:                -403.05
# No. Observations:                                                403   AIC:                             812.1
# Df Residuals:                                                    400   BIC:                             824.1
# Df Model:                                                          2
# Covariance Type:                                           nonrobust
# ...

# %%
df_ETH_log['Model'] = 7.9999 +  0.9874*df_ETH_log['ETH / Addresses, active, count' ]+ 0.5025*df_ETH_log['ETH / Transactions, transfers, value, mean, USD' ]

# %%
df_ETH_log[['Model','ETH / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df_ETH_log.index, df_ETH_log[['Model','ETH / Capitalization, market, current supply, USD']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %% [markdown]
# # Ripple

# %%
df_XRP = pd.read_excel('Chart-Sat Apr 29 2023 (4).xlsx',index_col='Time', parse_dates=True)

# %%
df_XRP = df_XRP.dropna()

# %%
df_XRP['XRP / Transactions, volume'] = df_XRP['XRP / Transactions, count, per second']*df_XRP['XRP / Transactions, transfers, value, mean, USD']

# %%
df_XRP_log = pd.DataFrame(np.log(df_XRP), columns=df_XRP.columns, index=df_XRP.index)

# %%
df_XRP_log = df_XRP_log.resample('W').mean()

# %%
df_XRP_log = df_XRP_log.join(df_FCI)

# %%
df_XRP_log= df_XRP_log.dropna()

# %%
df_XRP_log
# Out:
#             XRP / Price, USD  XRP / Addresses, active, count  \
# Time
# 2014-08-17         -5.051036                        7.060665
# 2014-08-24         -5.209927                        7.193430
# 2014-08-31         -5.312669                        7.163304
# 2014-09-07         -5.352283                        7.208085
# 2014-09-14         -5.370985                        7.150450
# ...                      ...                             ...
# 2023-03-26         -0.840026                       10.816007
# 2023-04-02         -0.654323                       10.782235
# 2023-04-09         -0.683177                       10.550201
# 2023-04-16         -0.659456                       10.459414
# 2023-04-23         -0.725573                       10.310764
#
#             XRP / Capitalization, market, current supply, USD  \
# Time
# 2014-08-17                                          20.277399
# 2014-08-24                                          20.118508
# ...

# %%
import statsmodels.api as sm
X = df_XRP_log[['XRP / Addresses, active, count','XRP / Transactions, volume','NFCI']]
y = df_XRP_log['XRP / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     XRP / Capitalization, market, current supply, USD   R-squared:                       0.919
# Model:                                                           OLS   Adj. R-squared:                  0.919
# Method:                                                Least Squares   F-statistic:                     1713.
# Date:                                               Sat, 29 Apr 2023   Prob (F-statistic):          1.14e-245
# Time:                                                       16:47:38   Log-Likelihood:                -368.02
# No. Observations:                                                454   AIC:                             744.0
# Df Residuals:                                                    450   BIC:                             760.5
# Df Model:                                                          3
# Covariance Type:                                           nonrobust
# ...

# %%
df_XRP_log['Model'] = 15.4581+0.1027*df_XRP_log['XRP / Addresses, active, count']+0.6879 *df_XRP_log['XRP / Transactions, volume']-0.7942*df_XRP_log['NFCI']

# %%
df_XRP_log[['Model','XRP / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df_XRP_log.index, df_XRP_log[['Model','XRP / Capitalization, market, current supply, USD']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %% [markdown]
# # Litecoin

# %%
df_LTC = pd.read_excel('Chart-Sat Apr 29 2023 (5).xlsx',index_col='Time', parse_dates=True)

# %%
df_LTC = df_LTC.dropna()

# %%
df_LTC['LTC / Transactions, volume'] = df_LTC['LTC / Transactions, count, per second']*df_LTC['LTC / Transactions, transfers, value, mean, USD']

# %%
df_LTC_log = pd.DataFrame(np.log(df_LTC), columns=df_LTC.columns, index=df_LTC.index)

# %%
df_LTC_log = df_LTC_log.resample('W').mean()

# %%
df_LTC_log = df_LTC_log.join(df_FCI)

# %%
df_LTC_log= df_LTC_log.dropna()

# %%
import statsmodels.api as sm
X = df_LTC_log[['LTC / Addresses, active, count','NFCI','LTC / Transactions, transfers, value, mean, USD']]
y = df_LTC_log['LTC / Capitalization, market, current supply, USD']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                                             OLS Regression Results
# ...
# Dep. Variable:     LTC / Capitalization, market, current supply, USD   R-squared:                       0.895
# Model:                                                           OLS   Adj. R-squared:                  0.894
# Method:                                                Least Squares   F-statistic:                     1477.
# Date:                                               Mon, 01 May 2023   Prob (F-statistic):          3.27e-254
# Time:                                                       15:02:04   Log-Likelihood:                -479.91
# No. Observations:                                                525   AIC:                             967.8
# Df Residuals:                                                    521   BIC:                             984.9
# Df Model:                                                          3
# Covariance Type:                                           nonrobust
# ...

# %%
df_LTC_log['Model']= 5.1006+1.2987*df_LTC_log['LTC / Addresses, active, count']+0.1981 *df_LTC_log['LTC / Transactions, transfers, value, mean, USD']-0.3186 *df_LTC_log['NFCI']

# %%
df_LTC_log[['Model','LTC / Capitalization, market, current supply, USD']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df_LTC_log.index, df_LTC_log[['Model','LTC / Capitalization, market, current supply, USD']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %% [markdown]
# # Netflix

# %%
Year	Number of paid subscribers
2001	400 thousand
2002	796 thousand
2003	1.41 million
2004	2.48 million
2005	4.02 million
2006	6.15 million
2007	7.32 million
2008	9.16 million
2009	11.89 million
2010	18.26 million
2011	24.30 million
2012	30.36 million
2013	41.43 million
2014	54.47 million
2015	70.83 million
2016	89.09 million
2017	110.64 million
2018	139.25 million
2019	167.09 million
2020	203.66 million
2021	209.18 million

# %%
df = pd.read_csv('NFLX.csv',index_col='Date', parse_dates=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...                ...         ...         ...         ...         ...
# 2023-04-24  330.200012  334.660004  326.750000  329.019989  329.019989
# 2023-04-25  328.500000  328.660004  321.100006  322.549988  322.549988
# 2023-04-26  321.359985  325.899994  320.470001  321.149994  321.149994
# 2023-04-27  324.299988  327.450012  317.440002  325.850006  325.850006
# 2023-04-28  325.239990  330.809998  324.000000  329.929993  329.929993
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# ...

# %%
df = df.resample('Y').mean()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-12-31    0.855974    0.884063    0.818251    0.850172    0.850172
# 2003-12-31    2.072242    2.140374    2.016678    2.081205    2.081205
# 2004-12-31    3.424325    3.507922    3.329025    3.413430    3.413430
# 2005-12-31    2.596978    2.654184    2.540368    2.597262    2.597262
# 2006-12-31    3.692254    3.753768    3.631736    3.690996    3.690996
# 2007-12-31    3.123734    3.178617    3.066096    3.123933    3.123933
# 2008-12-31    4.087244    4.199983    3.981875    4.094670    4.094670
# 2009-12-31    6.302472    6.434314    6.188855    6.322035    6.322035
# 2010-12-31   16.777222   17.138815   16.460249   16.824172   16.824172
# 2011-12-31   27.499665   28.021151   26.951270   27.493719   27.493719
# 2012-12-31   11.827480   12.124200   11.574623   11.855057   11.855057
# 2013-12-31   35.249762   35.875658   34.628787   35.271831   35.271831
# ...

# %%
df = df[:'2021-12-31']

# %%
df['Users'] = [796000 ,1410000 ,2480000 ,4020000 ,6150000 ,7320000 ,9160000 ,11890000 ,18260000,24300000 ,30360000 ,41430000 ,54470000,70830000 ,89090000,110640000,139250000,167090000,203660000,209180000]
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/1843835884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Users'] = [796000 ,1410000 ,2480000 ,4020000 ,6150000 ,7320000 ,9160000 ,11890000 ,18260000,24300000 ,30360000 ,41430000 ,54470000,70830000 ,89090000,110640000,139250000,167090000,203660000,209180000]

# %%
df_log = pd.DataFrame(np.log(df), columns=df.columns, index=df.index)

# %%
df_log
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2002-12-31 -0.155515 -0.123227 -0.200586 -0.162317  -0.162317  15.441090
# 2003-12-31  0.728631  0.760981  0.701452  0.732947   0.732947  16.642171
# 2004-12-31  1.230904  1.255024  1.202679  1.227718   1.227718  16.994284
# 2005-12-31  0.954349  0.976137  0.932309  0.954458   0.954458  16.179832
# 2006-12-31  1.306237  1.322760  1.289711  1.305896   1.305896  16.057883
# 2007-12-31  1.139029  1.156446  1.120405  1.139093   1.139093  16.240346
# 2008-12-31  1.407871  1.435080  1.381753  1.409686   1.409686  16.219786
# 2009-12-31  1.840942  1.861645  1.822750  1.844041   1.844041  16.259926
# 2010-12-31  2.820022  2.841346  2.800948  2.822817   2.822817  17.157705
# 2011-12-31  3.314174  3.332960  3.294030  3.313958   3.313958  17.608486
# 2012-12-31  2.470426  2.495203  2.448815  2.472755   2.472755  17.525755
# 2013-12-31  3.562459  3.580059  3.544685  3.563085   3.563085  17.127644
# ...

# %%
import statsmodels.api as sm
X = df_log[['Users']]
y = df_log['Close']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     276.3
# Date:                Sat, 29 Apr 2023   Prob (F-statistic):           2.28e-12
# Time:                        17:07:02   Log-Likelihood:                -14.250
# No. Observations:                  20   AIC:                             32.50
# Df Residuals:                      18   BIC:                             34.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -16.5857      1.193    -13.906      0.000     -19.091     -14.080
# ...

# %%
df_log['Model']=-16.5857 +1.1654*df_log['Users']

# %%
df_log[['Model','Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = pd.read_csv('^IXIC.csv',index_col='Date', parse_dates=True)

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#df = df[:'2002-12-31']

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
# Create the plot
plt.figure()
plt.plot(df.index, df['Close'])

# Save the plot as a PNG file
plt.savefig('time_series_plot.png', dpi=300, bbox_inches='tight')

# Show the plot (optional)
plt.show()

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df.index, df['Close'], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %%
yearly_data = df.resample('Y').mean()

yearly_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 1971-12-31    107.439301    107.439301    107.439301    107.439301
# 1972-12-31    128.526614    128.526614    128.526614    128.526614
# 1973-12-31    109.952857    109.952857    109.952857    109.952857
# 1974-12-31     76.286877     76.286877     76.286877     76.286877
# 1975-12-31     77.203952     77.203952     77.203952     77.203952
# 1976-12-31     89.898103     89.898103     89.898103     89.898103
# 1977-12-31     98.710119     98.710119     98.710119     98.710119
# 1978-12-31    117.525119    117.525119    117.525119    117.525119
# 1979-12-31    136.574545    136.574545    136.574545    136.574545
# 1980-12-31    168.608379    168.608379    168.608379    168.608379
# 1981-12-31    203.182371    203.182371    203.182371    203.182371
# 1982-12-31    188.972886    188.972886    188.972886    188.972886
# 1983-12-31    285.427786    285.427786    285.427786    285.427786
# ...

# %%
yearly_data = yearly_data['1995-12-31':'2022-12-31']

# %%
yearly_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 1995-12-31    924.797660    928.981748    920.239764    925.189961
# 1996-12-31   1165.113386   1170.596221   1158.117874   1164.948030
# 1997-12-31   1469.840827   1478.413083   1459.177906   1469.478379
# 1998-12-31   1794.772616   1809.293335   1778.038255   1794.907024
# 1999-12-31   2730.881518   2753.559884   2696.516470   2728.145995
# 2000-12-31   3797.171814   3851.036989   3719.621148   3783.673342
# 2001-12-31   2036.111413   2066.123667   2003.400319   2034.995924
# 2002-12-31   1541.918770   1559.593411   1521.217662   1539.731548
# 2003-12-31   1645.879645   1659.396150   1632.481746   1647.166944
# 2004-12-31   1986.853733   1999.180599   1973.889445   1986.525519
# 2005-12-31   2100.109091   2110.103170   2089.031113   2099.316307
# 2006-12-31   2263.186651   2275.518489   2249.793185   2263.409966
# 2007-12-31   2579.085580   2593.182786   2561.315383   2578.466608
# ...

# %%
yearly_data['Users'] = [16,36,70,147,248,361,458,587,719,817,1018,1093,1319,1574,1802,1971,2267,2497,2802,3079,3366,3696,4156,4313,4536,5053,5252,5544]
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/2053329392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_data['Users'] = [16,36,70,147,248,361,458,587,719,817,1018,1093,1319,1574,1802,1971,2267,2497,2802,3079,3366,3696,4156,4313,4536,5053,5252,5544]

# %%
#yearly_data['Users']= yearly_data['Users']/45

# %%
yearly_data['Metcalfe']= yearly_data['Users']**2
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/3188985631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_data['Metcalfe']= yearly_data['Users']**2

# %%
fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(yearly_data.index, yearly_data[['Close','Metcalfe']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()

# %%
import statsmodels.api as sm
X = yearly_data[['Users']]
y = yearly_data['Close']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     96.02
# Date:                Mon, 01 May 2023   Prob (F-statistic):           3.23e-10
# Time:                        15:22:01   Log-Likelihood:                -245.62
# No. Observations:                  28   AIC:                             495.2
# Df Residuals:                      26   BIC:                             497.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        488.0894    477.678      1.022      0.316    -493.791    1469.970
# ...

# %%
yearly_data['Metcalfe'] = 488.0894 + 1.7111*yearly_data['Users']
# Out:
# /var/folders/_b/28jfj19121qf32rdzd8twc000000gn/T/ipykernel_16654/3026747490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_data['Metcalfe'] = 488.0894 + 1.7111*yearly_data['Users']

# %%
df_log = pd.DataFrame(np.log(yearly_data), columns=yearly_data.columns, index=yearly_data.index)

# %%
import statsmodels.api as sm
X = df_log[['Users']]
y = df_log['Close']

# Add a constant to the independent variables to include an intercept in the model
X = sm.add_constant(X)

# Fit the multivariate regression model using ordinary least squares (OLS)
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     41.59
# Date:                Mon, 01 May 2023   Prob (F-statistic):           7.81e-07
# Time:                        15:22:03   Log-Likelihood:                -16.400
# No. Observations:                  28   AIC:                             36.80
# Df Residuals:                      26   BIC:                             39.47
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5463      0.397     13.976      0.000       4.731       6.362
# ...

# %%
df_log['Metcalfe'] = 5.5463 + 0.3589*df_log['Users']

# %%
df = np.exp(df_log)

fig = plt.figure(facecolor='none', edgecolor='none')  # Set figure background to transparent
plt.plot(df.index, df[['Close','Metcalfe']], alpha=0.5)  # Set the plot elements' transparency using alpha

# Save the plot as a transparent PNG file
plt.savefig('transparent_time_series_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot (optional)
plt.show()
